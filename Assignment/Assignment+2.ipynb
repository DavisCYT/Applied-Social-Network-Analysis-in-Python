# %% [markdown]
# ---
#
# _You are currently looking at **version 1.2** of this notebook. To download notebooks and datafiles, as well as get help on Jupyter notebooks in the Coursera platform, visit the [Jupyter Notebook FAQ](https://www.coursera.org/learn/python-social-network-analysis/resources/yPcBs) course resource._
#
# ---

# %% [markdown]
# # Assignment 2 - Network Connectivity
#
# In this assignment you will go through the process of importing and analyzing an internal email communication network between employees of a mid-sized manufacturing company.
# Each node represents an employee and each directed edge between two nodes represents an individual email. The left node represents the sender and the right node represents the recipient.

# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# This line must be commented out when submitting to the autograder
#!head email_network.txt

# %%
G = nx.DiGraph()

# %%
G.add_edges_from([('A', 'B') , ('A', 'C'), ('B', 'C'), ('C', 'A'), ('D', 'C')])

# %%
nx.draw_networkx(G)

# %%
h, a = nx.hits(G, normalized = True)

# %%
h,a = nx.hits(G, normalized = True)

# %%
h['C'], a['C']
# Out:
# (1.0065322483445805e-09, 0.7071067794684264)

# %%
h, a
# Out:
# ({'A': 0.41421356195612885,
#   'B': 0.2928932185186695,
#   'C': 1.0065322483445805e-09,
#   'D': 0.2928932185186695},
#  {'A': 2.429983801460681e-09,
#   'B': 0.29289321810158986,
#   'C': 0.7071067794684264,
#   'D': 0.0})

# %%
nx.pagerank(G)
# Out:
# {'A': 0.372526246091333,
#  'B': 0.19582365458881654,
#  'C': 0.39415009931985023,
#  'D': 0.037500000000000006}

# %%
h, a = nx.hits(G)

# %%
h['D'], a['D']
# Out:
# (0.2928932185186695, 0.0)

# %% [markdown]
# ### Question 1
#
# Using networkx, load up the directed multigraph from `email_network.txt`. Make sure the node names are strings.
#
# *This function should return a directed multigraph networkx graph.*

# %%
def answer_one():
    
    # Your Code Here
    G = nx.read_edgelist('email_network.txt', create_using = nx.MultiDiGraph(), data = [('time', str)])
    
    return G# Your Answer Here

# %%
type(answer_one())
# Out:
# networkx.classes.multidigraph.MultiDiGraph

# %% [markdown]
# ### Question 2
#
# How many employees and emails are represented in the graph from Question 1?
#
# *This function should return a tuple (#employees, #emails).*

# %%
def answer_two():
    
    G = answer_one()
    # Your Code Here
    
    return (len(G.nodes()), len(G.edges()))# Your Answer Here

# %% [markdown]
# ### Question 3
#
# * Part 1. Assume that information in this company can only be exchanged through email.
#
#     When an employee sends an email to another employee, a communication channel has been created, allowing the sender to provide information to the receiver, but not vice versa.
#
#     Based on the emails sent in the data, is it possible for information to go from every employee to every other employee?
#
#
# * Part 2. Now assume that a communication channel established by an email allows information to be exchanged both ways.
#
#     Based on the emails sent in the data, is it possible for information to go from every employee to every other employee?
#
#
# *This function should return a tuple of bools (part1, part2).*

# %%
def answer_three():
        
    # Your Code Here
    G = answer_one()
    
    return (nx.is_strongly_connected(G), nx.is_weakly_connected(G))# Your Answer Here

# %%
answer_three()
# Out:
# (False, True)

# %% [markdown]
# ### Question 4
#
# How many nodes are in the largest (in terms of nodes) weakly connected component?
#
# *This function should return an int.*

# %%
def answer_four():
        
    # Your Code Here
    G = answer_one()
    
    return (len(sorted(nx.weakly_connected_components(G), reverse = False)[0]))# Your Answer Here

# %%
answer_four()
# Out:
# 167

# %% [markdown]
# ### Question 5
#
# How many nodes are in the largest (in terms of nodes) strongly connected component?
#
# *This function should return an int*

# %%
def answer_five():
        
    # Your Code Here
    G = answer_one()
    scc = sorted(nx.strongly_connected_components(G))
    num = len(max(scc, key = len))
    
    return num# Your Answer Here

# %%
answer_five()
# Out:
# 126

# %% [markdown]
# ### Question 6
#
# Using the NetworkX function strongly_connected_component_subgraphs, find the subgraph of nodes in a largest strongly connected component.
# Call this graph G_sc.
#
# *This function should return a networkx MultiDiGraph named G_sc.*

# %%
def answer_six():
        
    # Your Code Here
    G = answer_one()
    G_sc = max(nx.strongly_connected_component_subgraphs(G), key = len)
    return G_sc# Your Answer Here

# %%
answer_six().edges()
# Out:
# [('124', '37'),
#  ('124', '40'),
#  ('124', '40'),
#  ('124', '40'),
#  ('124', '40'),
#  ('124', '40'),
#  ('124', '40'),
#  ('124', '93'),
#  ('124', '50'),
#  ('124', '50'),
#  ('124', '50'),
#  ('124', '50'),
#  ('124', '50'),
#  ('124', '50'),
#  ('124', '50'),
#  ('124', '50'),
#  ('124', '50'),
#  ('124', '50'),
#  ('124', '50'),
#  ('124', '50'),
#  ('124', '50'),
#  ('124', '50'),
#  ('124', '50'),
#  ('124', '50'),
#  ('124', '50'),
#  ('124', '50'),
#  ('124', '50'),
#  ('124', '50'),
#  ('124', '50'),
#  ('124', '50'),
#  ('124', '50'),
#  ('124', '50'),
#  ('124', '50'),
#  ('124', '50'),
#  ('124', '50'),
#  ('124', '50'),
#  ('124', '50'),
#  ('124', '50'),
#  ('124', '50'),
#  ('124', '50'),
#  ('124', '50'),
#  ('124', '50'),
#  ('124', '50'),
#  ('124', '45'),
#  ('124', '6'),
#  ('124', '6'),
#  ('124', '6'),
#  ('124', '46'),
#  ('124', '46'),
#  ('124', '121'),
#  ('124', '121'),
#  ('124', '1'),
#  ('124', '35'),
#  ('124', '106'),
#  ('124', '101'),
# ...

# %% [markdown]
# ### Question 7
#
# What is the average distance between nodes in G_sc?
#
# *This function should return a float.*

# %%
def answer_seven():
        
    # Your Code Here
    G_sc = answer_six()
    
    return nx.average_shortest_path_length(G_sc)# Your Answer Here

# %%
answer_seven()
# Out:
# 1.6461587301587302

# %% [markdown]
# ### Question 8
#
# What is the largest possible distance between two employees in G_sc?
#
# *This function should return an int.*

# %%
def answer_eight():
        
    # Your Code Here
    G_sc = answer_six()

    
    return nx.diameter(G_sc) # Your Answer Here

# %%
answer_eight()
# Out:
# 3

# %% [markdown]
# ### Question 9
#
# What is the set of nodes in G_sc with eccentricity equal to the diameter?
#
# *This function should return a set of the node(s).*

# %%
def answer_nine():
       
    # Your Code Here
    G_sc = answer_six()
    
    return set(nx.periphery(G_sc))# Your Answer Here

# %%
answer_nine()
# Out:
# {'129', '134', '97'}

# %% [markdown]
# ### Question 10
#
# What is the set of node(s) in G_sc with eccentricity equal to the radius?
#
# *This function should return a set of the node(s).*

# %%
def answer_ten():
        
    # Your Code Here
    G_sc = answer_six()
    
    return set(nx.center(G_sc))# Your Answer Here

# %%
answer_ten()
# Out:
# {'38'}

# %% [markdown]
# ### Question 11
#
# Which node in G_sc is connected to the most other nodes by a shortest path of length equal to the diameter of G_sc?
#
# How many nodes are connected to this node?
#
#
# *This function should return a tuple (name of node, number of satisfied connected nodes).*

# %%
def answer_eleven():
    
    # Your Code Here
    node_dict = dict()
    G_sc = answer_six()
    diameter = answer_eight()

    for node in G_sc.nodes():
        target_list = [ target for target, length in nx.shortest_path_length(G_sc, node).items() if length == diameter]
        node_dict[str(node)] = target_list
    #     for target, length in nx.shortest_path_length(G_sc, node).items():
    #         if length == diameter:
    #             target_list = []

    name = max(node_dict, key = lambda x : len(node_dict[x]))
    num = len(set(node_dict[name]))
    return (name, num)

# %%
answer_eleven()
# Out:
# ('97', 63)

# %% [markdown]
# ### Question 12
#
# Suppose you want to prevent communication from flowing to the node that you found in the previous question from any node in the center of G_sc, what is the smallest number of nodes you would need to remove from the graph (you're not allowed to remove the node from the previous question or the center nodes)?
#
# *This function should return an integer.*

# %%
G_sc = answer_six()
nx.center(G_sc)
# Out:
# ['38']

# %%
def answer_twelve():
#     G_sc = answer_six()
#     center = nx.center(G_sc)[0]
#     eleven = answer_eleven()[0]
#     direction_one = nx.node_connectivity(G_sc, center, eleven)
#     direction_two = nx.node_connectivity(G_sc, eleven, center)
#     # Your Code Here
    
#     return direction_one + direction_two# Your Answer Here
    G = answer_six()
    center = nx.center(G)[0]
    node = answer_eleven()[0]
    return len(nx.minimum_node_cut(G, center, node))

# %%
answer_twelve()
# Out:
# 5

# %% [markdown]
# ### Question 13
#
# Construct an undirected graph G_un using G_sc (you can ignore the attributes).
#
# *This function should return a networkx Graph.*

# %%
len(answer_six().edges())
# Out:
# 82130

# %%
G_x = answer_six().to_undirected()

# %%
G = nx.Graph()
for edge in G_x.edges():
    if edge in G:
        pass
    else:
        G.add_edge(edge[0], edge[1])

# %%
G.edges()
# Out:
# [('65', '50'),
#  ('65', '23'),
#  ('65', '74'),
#  ('65', '13'),
#  ('65', '59'),
#  ('65', '9'),
#  ('65', '45'),
#  ('65', '94'),
#  ('65', '37'),
#  ('65', '14'),
#  ('65', '95'),
#  ('65', '44'),
#  ('65', '92'),
#  ('65', '10'),
#  ('65', '112'),
#  ('65', '64'),
#  ('65', '4'),
#  ('65', '90'),
#  ('65', '1'),
#  ('65', '79'),
#  ('65', '104'),
#  ('65', '56'),
#  ('65', '47'),
#  ('65', '76'),
#  ('65', '72'),
#  ('65', '22'),
#  ('65', '98'),
#  ('65', '123'),
#  ('65', '17'),
#  ('65', '35'),
#  ('65', '73'),
#  ('65', '38'),
#  ('65', '40'),
#  ('65', '69'),
#  ('65', '68'),
#  ('65', '2'),
#  ('65', '86'),
#  ('65', '42'),
#  ('65', '80'),
#  ('65', '71'),
#  ('65', '12'),
#  ('65', '5'),
#  ('65', '11'),
#  ('65', '15'),
#  ('65', '7'),
#  ('65', '58'),
#  ('65', '49'),
#  ('65', '113'),
#  ('65', '117'),
#  ('50', '84'),
#  ('50', '45'),
#  ('50', '101'),
#  ('50', '30'),
#  ('50', '44'),
#  ('50', '3'),
#  ('50', '52'),
#  ('50', '39'),
#  ('50', '29'),
# ...

# %%
def answer_thirteen():
        
    # Your Code Here
    G_sc = answer_six()
    G_un = G_sc.to_undirected()
    G = nx.Graph()
    for edge in G_un.edges():
        if edge in G:
            pass
        else:
            G.add_edge(edge[0], edge[1])
    
    return G# Your Answer Here

# %%
type(answer_thirteen())
# Out:
# networkx.classes.graph.Graph

# %%
len(answer_thirteen().edges())
# Out:
# 3107

# %% [markdown]
# ### Question 14
#
# What is the transitivity and average clustering coefficient of graph G_un?
#
# *This function should return a tuple (transitivity, avg clustering).*

# %%
def answer_fourteen():
        
    # Your Code Here
    G_un = answer_thirteen()
    trans = nx.transitivity(G_un)
    clust = nx.average_clustering(G_un)
    
    return (trans, clust)# Your Answer Here

# %%
answer_fourteen()
# Out:
# (0.570111160700385, 0.6975272437231418)

# %%
G_un = answer_thirteen()

# %%
G_un.is_multigraph()
# Out:
# True

# %%
trans = nx.transitivity(G_un)
# Out:
# ---------------------------------------------------------------------------
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-84-de64e7d830f2> in <module>()
# ----> 1 trans = nx.transitivity(G_un)
#
# /opt/conda/lib/python3.6/site-packages/networkx/algorithms/cluster.py in transitivity(G)
#     284     triangles=0 # 6 times number of triangles
#     285     contri=0  # 2 times number of connected triples
# --> 286     for v,d,t in _triangles_and_degree_iter(G):
#     287         contri += d*(d-1)
#     288         triangles += t
#
# /opt/conda/lib/python3.6/site-packages/networkx/algorithms/cluster.py in _triangles_and_degree_iter(G, nodes)
#      65     """
#      66     if G.is_multigraph():
# ---> 67         raise NetworkXError("Not defined for multigraphs.")
#      68
#      69     if nodes is None:
#
# NetworkXError: Not defined for multigraphs.
